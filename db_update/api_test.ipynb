# %% [markdown]
# ## Ads Insights API 수집 가능 지표 확인

# %%
"""
Meta Ads Insights API - 특정 광고의 모든 데이터 수집기
=====================================================
아래 변수를 수정해서 사용하세요:
  - ACCESS_TOKEN : Meta API 액세스 토큰
  - AD_ID        : 조회할 광고 ID (act_XXXXXXX 형식이 아닌 순수 ad ID)
  - DATE_PRESET  : 조회 기간 preset (또는 DATE_SINCE/DATE_UNTIL로 커스텀 기간 지정)

실행:
  pip install facebook-business
  python meta_ads_insights_fetcher.py
"""

import json
import logging
from datetime import datetime
from facebook_business.api import FacebookAdsApi
from facebook_business.adobjects.ad import Ad

# =============================================================================
# ✏️  여기를 수정하세요
# =============================================================================
ACCESS_TOKEN = "EAALRoZCi9lYQBQZBWWXu67hjLrkvC17V9K5ZAK4UXvYD7Jtx34PvzhWZArK74Yla5xp0TjW6yd4SikRvu51fOCalZARRo36hgQmFQRqKTA3Uy9jy3LIDDl7C3eGSgKgFbEt4FQwEkqGw2TRgEJGDdvIU2xbEsZAjLQQZCGkCij2Gap9ZBPZCZBU3mzg5el8ZCZBftDCV"
APP_ID       = "793452136469892"         # 없으면 빈 문자열 ""로 두세요
APP_SECRET   = "93c2766fd2a15b7f7997f4586085a4ac"     # 없으면 빈 문자열 ""로 두세요

AD_ID        = "6901235189529"          # 예: "23851234567890"

# 기간 설정 (DATE_PRESET 또는 DATE_SINCE/DATE_UNTIL 둘 중 하나만 사용)
USE_DATE_PRESET = True                    # True면 preset, False면 since/until 사용
DATE_PRESET     = "maximum"              # today / yesterday / last_7d / last_30d / last_90d / this_month / last_month / maximum
DATE_SINCE      = "2025-01-01"            # USE_DATE_PRESET=False일 때 사용
DATE_UNTIL      = "2025-03-25"            # USE_DATE_PRESET=False일 때 사용
# =============================================================================

# 로그 설정
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger(__name__)


# =============================================================================
# 필드 정의
# =============================================================================

# breakdown 없이 조회 가능한 모든 필드
# (breakdown과 함께 요청 불가한 5개 필드는 별도 그룹으로 분리)
FIELDS_WITHOUT_BREAKDOWN = [
    # 기본 식별 정보
    "ad_id",
    "ad_name",
    "adset_id",
    "adset_name",
    "campaign_id",
    "campaign_name",
    "account_id",
    "account_name",

    # 노출·도달
    "impressions",
    "reach",
    "frequency",

    # 클릭
    "clicks",
    "inline_link_clicks",
    "inline_post_engagement",
    "outbound_clicks",
    "unique_clicks",
    "unique_inline_link_clicks",
    "unique_outbound_clicks",

    # 비용
    "spend",
    "cpm",
    "cpc",
    "ctr",
    "cpp",
    "cost_per_inline_link_click",
    "cost_per_unique_click",
    "cost_per_outbound_click",

    # 전환·액션 (action_type breakdown으로 내부 분류됨)
    "actions",
    "action_values",
    "conversions",
    "conversion_values",
    "cost_per_action_type",
    "cost_per_conversion",
    "cost_per_unique_action_type",
    "unique_actions",

    # ROAS
    "purchase_roas",
    "website_purchase_roas",

    # 동영상
    "video_avg_time_watched_actions",
    "video_p25_watched_actions",
    "video_p50_watched_actions",
    "video_p75_watched_actions",
    "video_p95_watched_actions",
    "video_p100_watched_actions",
    "video_thruplay_watched_actions",
    "video_30_sec_watched_actions",
    "video_continuous_2_sec_watched_actions",
    "video_play_actions",
    "video_play_curve_actions",

    # 광고 상기
    "estimated_ad_recallers",
    "estimated_ad_recall_rate",

    # 소셜
    "social_spend",

    # 기타
    "objective",
    "buying_type",
    "quality_ranking",
    "engagement_rate_ranking",
    "conversion_rate_ranking",
]

# breakdown 없이 단독으로만 요청 가능한 필드 (breakdown과 함께 요청하면 API 오류)
FIELDS_NO_BREAKDOWN_ONLY = [
    "app_store_clicks",
    "newsfeed_avg_position",
    "newsfeed_clicks",
    "newsfeed_impressions",
    # relevance_score는 완전 deprecated되어 제외
]

# age+gender breakdown과 함께 요청 가능한 필드
# (reach/unique_* 는 포함하되 13개월 제한 주의 - 30일 기간이면 문제없음)
FIELDS_WITH_BREAKDOWN = [
    "impressions",
    "reach",
    "clicks",
    "inline_link_clicks",
    "spend",
    "cpm",
    "cpc",
    "ctr",
    "cpp",
    "actions",
    "action_values",
    "conversions",
    "conversion_values",
    "cost_per_action_type",
    "cost_per_conversion",
    "purchase_roas",
    "website_purchase_roas",
    "unique_clicks",
    "unique_actions",
    "unique_ctr",
    "estimated_ad_recallers",
    "estimated_ad_recall_rate",
    "video_avg_time_watched_actions",
    "video_p25_watched_actions",
    "video_p50_watched_actions",
    "video_p75_watched_actions",
    "video_p95_watched_actions",
    "video_p100_watched_actions",
    "video_thruplay_watched_actions",
    "video_30_sec_watched_actions",
]


# =============================================================================
# 유틸
# =============================================================================

def build_params(extra: dict = None) -> dict:
    """공통 파라미터 빌드"""
    params = {}
    if USE_DATE_PRESET:
        params["date_preset"] = DATE_PRESET
    else:
        params["time_range"] = {"since": DATE_SINCE, "until": DATE_UNTIL}
    if extra:
        params.update(extra)
    return params


def pretty(data) -> str:
    """JSON 예쁘게 출력"""
    return json.dumps(data, indent=2, ensure_ascii=False, default=str)


def log_section(title: str):
    log.info("=" * 70)
    log.info(f"  {title}")
    log.info("=" * 70)


def fetch_insights(ad: Ad, fields: list, params: dict, label: str) -> list:
    """insights 조회 후 로그 출력, 결과 반환"""
    log_section(label)
    log.info(f"요청 fields  : {fields}")
    log.info(f"요청 params  : {pretty(params)}")
    try:
        insights = ad.get_insights(fields=fields, params=params)
        results = [dict(row) for row in insights]
        if results:
            log.info(f"응답 ({len(results)}건):\n{pretty(results)}")
        else:
            log.warning("응답 데이터 없음 (해당 기간 데이터 없거나 광고 미게재)")
        return results
    except Exception as e:
        log.error(f"API 오류: {e}")
        return []


# =============================================================================
# 메인
# =============================================================================

def main():
    log.info(f"Meta Ads Insights 수집 시작 - {datetime.now().isoformat()}")
    log.info(f"AD_ID        : {AD_ID}")
    log.info(f"기간         : {DATE_PRESET if USE_DATE_PRESET else f'{DATE_SINCE} ~ {DATE_UNTIL}'}")

    # API 초기화
    FacebookAdsApi.init(
        app_id=APP_ID or None,
        app_secret=APP_SECRET or None,
        access_token=ACCESS_TOKEN,
    )
    ad = Ad(AD_ID)

    # ------------------------------------------------------------------
    # 0. API 버전 확인
    # ------------------------------------------------------------------
    api = FacebookAdsApi.get_default_api()
    log.info(f"사용 중인 Meta API 버전: {api.API_VERSION}")

    # ------------------------------------------------------------------
    # 1. breakdown 없이 — 전체 지표
    # ------------------------------------------------------------------
    fetch_insights(
        ad=ad,
        fields=FIELDS_WITHOUT_BREAKDOWN,
        params=build_params(),
        label="[1/3] breakdown 없음 — 전체 지표",
    )

    # ------------------------------------------------------------------
    # 2. breakdown 없이만 가능한 필드 (newsfeed_*, app_store_clicks)
    # ------------------------------------------------------------------
    fetch_insights(
        ad=ad,
        fields=FIELDS_NO_BREAKDOWN_ONLY,
        params=build_params(),
        label="[2/3] breakdown 없이만 조회 가능한 필드 (newsfeed_* / app_store_clicks)",
    )

    # ------------------------------------------------------------------
    # 3. age + gender breakdown
    # ------------------------------------------------------------------
    fetch_insights(
        ad=ad,
        fields=FIELDS_WITH_BREAKDOWN,
        params=build_params({"breakdowns": ["age", "gender"]}),
        label="[3/3] age + gender breakdown",
    )

    log.info("=" * 70)
    log.info(f"수집 완료 - {datetime.now().isoformat()}")
    log.info("=" * 70)

    # ------------------------------------------------------------------
    # 참고: breakdown 값의 합산 ≠ 전체값 주의사항 출력
    # ------------------------------------------------------------------
    log.warning(
        "⚠️  reach / unique_* 계열은 breakdown 합산값 ≠ 전체값입니다. "
        "고유 사용자 중복 제거 방식 차이로 인해 breakdown별 reach 합산이 "
        "전체 reach보다 크게 나올 수 있습니다."
    )


if __name__ == "__main__":
    main()
# Out:
# 2026-03-26 18:34:58 [INFO] Meta Ads Insights 수집 시작 - 2026-03-26T18:34:58.306269
# 2026-03-26 18:34:58 [INFO] AD_ID        : 6901235189529
# 2026-03-26 18:34:58 [INFO] 기간         : maximum
# 2026-03-26 18:34:58 [INFO] 사용 중인 Meta API 버전: v25.0
# 2026-03-26 18:34:58 [INFO] ======================================================================
# 2026-03-26 18:34:58 [INFO]   [1/3] breakdown 없음 — 전체 지표
# 2026-03-26 18:34:58 [INFO] ======================================================================
# 2026-03-26 18:34:58 [INFO] 요청 fields  : ['ad_id', 'ad_name', 'adset_id', 'adset_name', 'campaign_id', 'campaign_name', 'account_id', 'account_name', 'impressions', 'reach', 'frequency', 'clicks', 'inline_link_clicks', 'inline_post_engagement', 'outbound_clicks', 'unique_clicks', 'unique_inline_link_clicks', 'unique_outbound_clicks', 'spend', 'cpm', 'cpc', 'ctr', 'cpp', 'cost_per_inline_link_click', 'cost_per_unique_click', 'cost_per_outbound_click', 'actions', 'action_values', 'conversions', 'conversion_values', 'cost_per_action_type', 'cost_per_conversion', 'cost_per_unique_action_type', 'unique_actions', 'purchase_roas', 'website_purchase_roas', 'video_avg_time_watched_actions', 'video_p25_watched_actions', 'video_p50_watched_actions', 'video_p75_watched_actions', 'video_p95_watched_actions', 'video_p100_watched_actions', 'video_thruplay_watched_actions', 'video_30_sec_watched_actions', 'video_continuous_2_sec_watched_actions', 'video_play_actions', 'video_play_curve_actions', 'estimated_ad_recallers', 'estimated_ad_recall_rate', 'social_spend', 'objective', 'buying_type', 'quality_ranking', 'engagement_rate_ranking', 'conversion_rate_ranking']
# 2026-03-26 18:34:58 [INFO] 요청 params  : {
#   "date_preset": "maximum"
# }
# 2026-03-26 18:34:59 [INFO] 응답 (1건):
# [
#   {
#     "ad_id": "6901235189529",
#     "ad_name": "구매전환 오늘도 커피로 하루를 시작하셨나요?",
#     "adset_id": "6901235189329",
#     "adset_name": "구매전환 오늘도 커피로 하루를 시작하셨나요?",
#     "campaign_id": "6901235041929",
#     "campaign_name": "2026 1/4 구매전환_Depart",
#     "account_id": "618278251632554",
#     "account_name": "네츄럴굿띵스",
#     "impressions": "1037",
#     "reach": "580",
#     "frequency": "1.787931",
#     "clicks": "29",
#     "inline_link_clicks": "25",
#     "inline_post_engagement": "75",
#     "outbound_clicks": [
#       {
#         "action_type": "outbound_click",
#         "value": "25"
#       }
#     ],
#     "unique_clicks": "28",
#     "unique_inline_link_clicks": "25",
#     "unique_outbound_clicks": [
#       {
#         "action_type": "outbound_click",
#         "value": "25"
#       }
#     ],
#     "spend": "31349",
#     "cpm": "30230.472517",
#     "cpc": "1081",
#     "ctr": "2.796528",
#     "cpp": "54050",
#     "cost_per_inline_link_click": "1253.96",
#     "cost_per_unique_click": "1119.607143",
#     "cost_per_outbound_click": [
#       {
#         "action_type": "outbound_click",
#         "value": "1253.96"
#       }
#     ],
#     "actions": [
#       {
#         "action_type": "web_in_store_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "link_click",
#         "value": "25"
#       },
#       {
#         "action_type": "omni_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_initiated_checkout",
#         "value": "1"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "75"
#       },
#       {
#         "action_type": "purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "134"
#       },
#       {
#         "action_type": "add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "134"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "26"
#       },
#       {
#         "action_type": "onsite_web_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "post_interaction_gross",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "26"
#       },
#       {
#         "action_type": "view_content",
#         "value": "26"
#       },
#       {
#         "action_type": "web_app_in_store_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "75"
#       },
#       {
#         "action_type": "onsite_conversion.post_unlike",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_conversion.post_net_like",
#         "value": "0"
#       },
#       {
#         "action_type": "onsite_web_initiate_checkout",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "26"
#       },
#       {
#         "action_type": "onsite_web_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "video_view",
#         "value": "49"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "26"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "26"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "post_reaction",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_initiate_checkout",
#         "value": "1"
#       },
#       {
#         "action_type": "initiate_checkout",
#         "value": "1"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "onsite_web_app_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_app_add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_initiate_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_initiated_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "1393800"
#       },
#       {
#         "action_type": "web_app_in_store_purchase",
#         "value": "540"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "1393800"
#       },
#       {
#         "action_type": "add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "1393800"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_initiate_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "1393800"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "1393800"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "initiate_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "web_in_store_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_add_to_cart",
#         "value": "54000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "web_in_store_purchase",
#         "value": "31349"
#       },
#       {
#         "action_type": "omni_purchase",
#         "value": "31349"
#       },
#       {
#         "action_type": "initiate_checkout",
#         "value": "31349"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "1205.730769"
#       },
#       {
#         "action_type": "video_view",
#         "value": "639.77551"
#       },
#       {
#         "action_type": "link_click",
#         "value": "1253.96"
#       },
#       {
#         "action_type": "post_interaction_gross",
#         "value": "31349"
#       },
#       {
#         "action_type": "onsite_web_initiate_checkout",
#         "value": "31349"
#       },
#       {
#         "action_type": "onsite_web_purchase",
#         "value": "31349"
#       },
#       {
#         "action_type": "view_content",
#         "value": "1205.730769"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "417.986667"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "1205.730769"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "233.947761"
#       },
#       {
#         "action_type": "purchase",
#         "value": "31349"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "417.986667"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "233.947761"
#       },
#       {
#         "action_type": "omni_initiated_checkout",
#         "value": "31349"
#       },
#       {
#         "action_type": "omni_add_to_cart",
#         "value": "31349"
#       },
#       {
#         "action_type": "add_to_cart",
#         "value": "31349"
#       }
#     ],
#     "cost_per_unique_action_type": [
#       {
#         "action_type": "link_click",
#         "value": "1253.96"
#       }
#     ],
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "25"
#       }
#     ],
#     "purchase_roas": [
#       {
#         "action_type": "omni_purchase",
#         "value": "1.722543"
#       }
#     ],
#     "website_purchase_roas": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_purchase",
#         "value": "1.722543"
#       }
#     ],
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "22"
#       }
#     ],
#     "video_p50_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "10"
#       }
#     ],
#     "video_p75_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "4"
#       }
#     ],
#     "video_p95_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p100_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_thruplay_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "5"
#       }
#     ],
#     "video_30_sec_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_play_actions": [
#       {
#         "action_type": "video_view",
#         "value": "253"
#       }
#     ],
#     "video_play_curve_actions": [
#       {
#         "action_type": "video_view",
#         "value": [
#           100,
#           57,
#           27,
#           19,
#           13,
#           10,
#           8,
#           6,
#           5,
#           4,
#           4,
#           3,
#           3,
#           2,
#           3,
#           2,
#           1,
#           0,
#           0,
#           0,
#           0,
#           0
#         ]
#       }
#     ],
#     "social_spend": "0",
#     "objective": "OUTCOME_SALES",
#     "buying_type": "AUCTION",
#     "quality_ranking": "UNKNOWN",
#     "engagement_rate_ranking": "UNKNOWN",
#     "conversion_rate_ranking": "UNKNOWN",
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26"
#   }
# ]
# 2026-03-26 18:34:59 [INFO] ======================================================================
# 2026-03-26 18:34:59 [INFO]   [2/3] breakdown 없이만 조회 가능한 필드 (newsfeed_* / app_store_clicks)
# 2026-03-26 18:34:59 [INFO] ======================================================================
# 2026-03-26 18:34:59 [INFO] 요청 fields  : ['app_store_clicks', 'newsfeed_avg_position', 'newsfeed_clicks', 'newsfeed_impressions']
# 2026-03-26 18:34:59 [INFO] 요청 params  : {
#   "date_preset": "maximum"
# }
# 2026-03-26 18:34:59 [ERROR] API 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/6901235189529/insights
#   Params:  {'date_preset': 'maximum', 'fields': 'app_store_clicks,newsfeed_avg_position,newsfeed_clicks,newsfeed_impressions'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) app_store_clicks, newsfeed_avg_position, newsfeed_clicks, newsfeed_impressions are not valid for fields param. please check https://developers.facebook.com/docs/marketing-api/reference/ads-insights/ for all valid values",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A6rPRhNff1WTjmvt8B7-Z9S"
#       }
#     }
#
# 2026-03-26 18:34:59 [INFO] ======================================================================
# 2026-03-26 18:34:59 [INFO]   [3/3] age + gender breakdown
# 2026-03-26 18:34:59 [INFO] ======================================================================
# 2026-03-26 18:34:59 [INFO] 요청 fields  : ['impressions', 'reach', 'clicks', 'inline_link_clicks', 'spend', 'cpm', 'cpc', 'ctr', 'cpp', 'actions', 'action_values', 'conversions', 'conversion_values', 'cost_per_action_type', 'cost_per_conversion', 'purchase_roas', 'website_purchase_roas', 'unique_clicks', 'unique_actions', 'unique_ctr', 'estimated_ad_recallers', 'estimated_ad_recall_rate', 'video_avg_time_watched_actions', 'video_p25_watched_actions', 'video_p50_watched_actions', 'video_p75_watched_actions', 'video_p95_watched_actions', 'video_p100_watched_actions', 'video_thruplay_watched_actions', 'video_30_sec_watched_actions']
# 2026-03-26 18:34:59 [INFO] 요청 params  : {
#   "date_preset": "maximum",
#   "breakdowns": [
#     "age",
#     "gender"
#   ]
# }
# 2026-03-26 18:35:00 [INFO] 응답 (13건):
# [
#   {
#     "impressions": "70",
#     "reach": "32",
#     "clicks": "3",
#     "inline_link_clicks": "3",
#     "spend": "1144",
#     "cpm": "16342.857143",
#     "cpc": "381.333333",
#     "ctr": "4.285714",
#     "cpp": "35750",
#     "actions": [
#       {
#         "action_type": "link_click",
#         "value": "3"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "5"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "3"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "3"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "5"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "3"
#       },
#       {
#         "action_type": "video_view",
#         "value": "2"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "3"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "162000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "omni_view_content",
#         "value": "381.333333"
#       },
#       {
#         "action_type": "video_view",
#         "value": "572"
#       },
#       {
#         "action_type": "link_click",
#         "value": "381.333333"
#       },
#       {
#         "action_type": "view_content",
#         "value": "381.333333"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "228.8"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "381.333333"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "381.333333"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "228.8"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "381.333333"
#       }
#     ],
#     "unique_clicks": "3",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "3"
#       }
#     ],
#     "unique_ctr": "9.375",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "3"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p50_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_thruplay_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "18-24",
#     "gender": "female"
#   },
#   {
#     "impressions": "14",
#     "reach": "7",
#     "clicks": "0",
#     "inline_link_clicks": "0",
#     "spend": "129",
#     "cpm": "9214.285714",
#     "ctr": "0",
#     "cpp": "18428.571429",
#     "unique_clicks": "0",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "18-24",
#     "gender": "male"
#   },
#   {
#     "impressions": "311",
#     "reach": "180",
#     "clicks": "11",
#     "inline_link_clicks": "10",
#     "spend": "6945",
#     "cpm": "22331.189711",
#     "cpc": "631.363636",
#     "ctr": "3.536977",
#     "cpp": "38583.333333",
#     "actions": [
#       {
#         "action_type": "link_click",
#         "value": "10"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "23"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "122"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "122"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "14"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "14"
#       },
#       {
#         "action_type": "view_content",
#         "value": "14"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "23"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "14"
#       },
#       {
#         "action_type": "video_view",
#         "value": "13"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "14"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "14"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "745800"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "745800"
#       },
#       {
#         "action_type": "view_content",
#         "value": "745800"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "745800"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "745800"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "omni_view_content",
#         "value": "496.071429"
#       },
#       {
#         "action_type": "video_view",
#         "value": "534.230769"
#       },
#       {
#         "action_type": "link_click",
#         "value": "694.5"
#       },
#       {
#         "action_type": "view_content",
#         "value": "496.071429"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "301.956522"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "496.071429"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "56.92623"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "301.956522"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "56.92623"
#       }
#     ],
#     "unique_clicks": "11",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "10"
#       }
#     ],
#     "unique_ctr": "6.111111",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "3"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "25-34",
#     "gender": "female"
#   },
#   {
#     "impressions": "43",
#     "reach": "24",
#     "clicks": "3",
#     "inline_link_clicks": "1",
#     "spend": "881",
#     "cpm": "20488.372093",
#     "cpc": "293.666667",
#     "ctr": "6.976744",
#     "cpp": "36708.333333",
#     "actions": [
#       {
#         "action_type": "link_click",
#         "value": "1"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "4"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "4"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "1"
#       },
#       {
#         "action_type": "video_view",
#         "value": "3"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "1"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "54000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "omni_view_content",
#         "value": "881"
#       },
#       {
#         "action_type": "video_view",
#         "value": "293.666667"
#       },
#       {
#         "action_type": "link_click",
#         "value": "881"
#       },
#       {
#         "action_type": "view_content",
#         "value": "881"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "220.25"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "881"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "881"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "220.25"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "881"
#       }
#     ],
#     "unique_clicks": "2",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "1"
#       }
#     ],
#     "unique_ctr": "8.333333",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "25-34",
#     "gender": "male"
#   },
#   {
#     "impressions": "376",
#     "reach": "197",
#     "clicks": "5",
#     "inline_link_clicks": "4",
#     "spend": "11697",
#     "cpm": "31109.042553",
#     "cpc": "2339.4",
#     "ctr": "1.329787",
#     "cpp": "59375.634518",
#     "actions": [
#       {
#         "action_type": "web_in_store_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "link_click",
#         "value": "4"
#       },
#       {
#         "action_type": "omni_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_initiated_checkout",
#         "value": "1"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "24"
#       },
#       {
#         "action_type": "purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "3"
#       },
#       {
#         "action_type": "add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "3"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "onsite_web_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "web_app_in_store_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "24"
#       },
#       {
#         "action_type": "onsite_conversion.post_unlike",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_conversion.post_net_like",
#         "value": "0"
#       },
#       {
#         "action_type": "onsite_web_initiate_checkout",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "3"
#       },
#       {
#         "action_type": "onsite_web_purchase",
#         "value": "1"
#       },
#       {
#         "action_type": "video_view",
#         "value": "20"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "3"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_initiate_checkout",
#         "value": "1"
#       },
#       {
#         "action_type": "initiate_checkout",
#         "value": "1"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "onsite_web_app_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_app_add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_initiate_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_initiated_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "web_app_in_store_purchase",
#         "value": "540"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_initiate_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "162000"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "initiate_checkout",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_add_to_cart",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "web_in_store_purchase",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_add_to_cart",
#         "value": "54000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "web_in_store_purchase",
#         "value": "11697"
#       },
#       {
#         "action_type": "omni_purchase",
#         "value": "11697"
#       },
#       {
#         "action_type": "initiate_checkout",
#         "value": "11697"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "3899"
#       },
#       {
#         "action_type": "video_view",
#         "value": "584.85"
#       },
#       {
#         "action_type": "link_click",
#         "value": "2924.25"
#       },
#       {
#         "action_type": "onsite_web_initiate_checkout",
#         "value": "11697"
#       },
#       {
#         "action_type": "onsite_web_purchase",
#         "value": "11697"
#       },
#       {
#         "action_type": "view_content",
#         "value": "3899"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "487.375"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "3899"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "3899"
#       },
#       {
#         "action_type": "purchase",
#         "value": "11697"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "487.375"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "3899"
#       },
#       {
#         "action_type": "omni_initiated_checkout",
#         "value": "11697"
#       },
#       {
#         "action_type": "omni_add_to_cart",
#         "value": "11697"
#       },
#       {
#         "action_type": "add_to_cart",
#         "value": "11697"
#       }
#     ],
#     "purchase_roas": [
#       {
#         "action_type": "omni_purchase",
#         "value": "4.616568"
#       }
#     ],
#     "website_purchase_roas": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_purchase",
#         "value": "4.616568"
#       }
#     ],
#     "unique_clicks": "5",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "4"
#       }
#     ],
#     "unique_ctr": "2.538071",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "10"
#       }
#     ],
#     "video_p50_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "5"
#       }
#     ],
#     "video_p75_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "3"
#       }
#     ],
#     "video_p95_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_p100_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_thruplay_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "3"
#       }
#     ],
#     "video_30_sec_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "35-44",
#     "gender": "female"
#   },
#   {
#     "impressions": "41",
#     "reach": "25",
#     "clicks": "2",
#     "inline_link_clicks": "2",
#     "spend": "901",
#     "cpm": "21975.609756",
#     "cpc": "450.5",
#     "ctr": "4.878049",
#     "cpp": "36040",
#     "actions": [
#       {
#         "action_type": "link_click",
#         "value": "2"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "3"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "2"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "2"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "2"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "2"
#       },
#       {
#         "action_type": "view_content",
#         "value": "2"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "3"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "2"
#       },
#       {
#         "action_type": "video_view",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "2"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "2"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "108000"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "108000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "108000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "108000"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "108000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "omni_view_content",
#         "value": "450.5"
#       },
#       {
#         "action_type": "video_view",
#         "value": "901"
#       },
#       {
#         "action_type": "link_click",
#         "value": "450.5"
#       },
#       {
#         "action_type": "view_content",
#         "value": "450.5"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "300.333333"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "450.5"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "450.5"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "300.333333"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "450.5"
#       }
#     ],
#     "unique_clicks": "2",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "2"
#       }
#     ],
#     "unique_ctr": "8",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_p50_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "35-44",
#     "gender": "male"
#   },
#   {
#     "impressions": "2",
#     "reach": "2",
#     "clicks": "0",
#     "inline_link_clicks": "0",
#     "spend": "157",
#     "cpm": "78500",
#     "ctr": "0",
#     "cpp": "78500",
#     "unique_clicks": "0",
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "35-44",
#     "gender": "unknown"
#   },
#   {
#     "impressions": "140",
#     "reach": "86",
#     "clicks": "3",
#     "inline_link_clicks": "3",
#     "spend": "7220",
#     "cpm": "51571.428571",
#     "cpc": "2406.666667",
#     "ctr": "2.142857",
#     "cpp": "83953.488372",
#     "actions": [
#       {
#         "action_type": "link_click",
#         "value": "3"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "11"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "post_interaction_gross",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "11"
#       },
#       {
#         "action_type": "onsite_conversion.post_net_like",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "1"
#       },
#       {
#         "action_type": "video_view",
#         "value": "7"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "post_reaction",
#         "value": "1"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "54000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "omni_view_content",
#         "value": "7220"
#       },
#       {
#         "action_type": "video_view",
#         "value": "1031.428571"
#       },
#       {
#         "action_type": "link_click",
#         "value": "2406.666667"
#       },
#       {
#         "action_type": "post_interaction_gross",
#         "value": "7220"
#       },
#       {
#         "action_type": "view_content",
#         "value": "7220"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "656.363636"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "7220"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "7220"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "656.363636"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "7220"
#       }
#     ],
#     "unique_clicks": "3",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "3"
#       }
#     ],
#     "unique_ctr": "3.488372",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "3"
#       }
#     ],
#     "video_p50_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p75_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_p95_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_p100_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_thruplay_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_30_sec_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "45-54",
#     "gender": "female"
#   },
#   {
#     "impressions": "9",
#     "reach": "8",
#     "clicks": "0",
#     "inline_link_clicks": "0",
#     "spend": "542",
#     "cpm": "60222.222222",
#     "ctr": "0",
#     "cpp": "67750",
#     "actions": [
#       {
#         "action_type": "page_engagement",
#         "value": "1"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "1"
#       },
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "video_view",
#         "value": "542"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "542"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "542"
#       }
#     ],
#     "unique_clicks": "0",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "45-54",
#     "gender": "male"
#   },
#   {
#     "impressions": "2",
#     "reach": "1",
#     "clicks": "0",
#     "inline_link_clicks": "0",
#     "spend": "69",
#     "cpm": "34500",
#     "ctr": "0",
#     "cpp": "69000",
#     "unique_clicks": "0",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "7"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "45-54",
#     "gender": "unknown"
#   },
#   {
#     "impressions": "22",
#     "reach": "16",
#     "clicks": "1",
#     "inline_link_clicks": "1",
#     "spend": "1207",
#     "cpm": "54863.636364",
#     "cpc": "1207",
#     "ctr": "4.545455",
#     "cpp": "75437.5",
#     "actions": [
#       {
#         "action_type": "link_click",
#         "value": "1"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "2"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "2"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "1"
#       },
#       {
#         "action_type": "video_view",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "1"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "54000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "omni_view_content",
#         "value": "1207"
#       },
#       {
#         "action_type": "video_view",
#         "value": "1207"
#       },
#       {
#         "action_type": "link_click",
#         "value": "1207"
#       },
#       {
#         "action_type": "view_content",
#         "value": "1207"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "603.5"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "1207"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "1207"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "603.5"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "1207"
#       }
#     ],
#     "unique_clicks": "1",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "1"
#       }
#     ],
#     "unique_ctr": "6.25",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "2"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "55-64",
#     "gender": "female"
#   },
#   {
#     "impressions": "6",
#     "reach": "5",
#     "clicks": "1",
#     "inline_link_clicks": "1",
#     "spend": "212",
#     "cpm": "35333.333333",
#     "cpc": "212",
#     "ctr": "16.666667",
#     "cpp": "42400",
#     "actions": [
#       {
#         "action_type": "link_click",
#         "value": "1"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "2"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "2"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "1"
#       },
#       {
#         "action_type": "video_view",
#         "value": "1"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "1"
#       },
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "1"
#       }
#     ],
#     "action_values": [
#       {
#         "action_type": "offsite_conversion.fb_pixel_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "omni_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_view_content",
#         "value": "54000"
#       },
#       {
#         "action_type": "onsite_web_app_view_content",
#         "value": "54000"
#       }
#     ],
#     "cost_per_action_type": [
#       {
#         "action_type": "omni_view_content",
#         "value": "212"
#       },
#       {
#         "action_type": "video_view",
#         "value": "212"
#       },
#       {
#         "action_type": "link_click",
#         "value": "212"
#       },
#       {
#         "action_type": "view_content",
#         "value": "212"
#       },
#       {
#         "action_type": "post_engagement",
#         "value": "106"
#       },
#       {
#         "action_type": "offsite_content_view_add_meta_leads",
#         "value": "212"
#       },
#       {
#         "action_type": "landing_page_view",
#         "value": "212"
#       },
#       {
#         "action_type": "page_engagement",
#         "value": "106"
#       },
#       {
#         "action_type": "omni_landing_page_view",
#         "value": "212"
#       }
#     ],
#     "unique_clicks": "1",
#     "unique_actions": [
#       {
#         "action_type": "link_click",
#         "value": "1"
#       }
#     ],
#     "unique_ctr": "20",
#     "video_avg_time_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "8"
#       }
#     ],
#     "video_p25_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "video_p50_watched_actions": [
#       {
#         "action_type": "video_view",
#         "value": "1"
#       }
#     ],
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "55-64",
#     "gender": "male"
#   },
#   {
#     "impressions": "1",
#     "reach": "1",
#     "clicks": "0",
#     "inline_link_clicks": "0",
#     "spend": "245",
#     "cpm": "245000",
#     "ctr": "0",
#     "cpp": "245000",
#     "unique_clicks": "0",
#     "date_start": "2026-01-21",
#     "date_stop": "2026-03-26",
#     "age": "65+",
#     "gender": "female"
#   }
# ]
# 2026-03-26 18:35:00 [INFO] ======================================================================
# 2026-03-26 18:35:00 [INFO] 수집 완료 - 2026-03-26T18:35:00.306453
# 2026-03-26 18:35:00 [INFO] ======================================================================
# 2026-03-26 18:35:00 [WARNING] ⚠️  reach / unique_* 계열은 breakdown 합산값 ≠ 전체값입니다. 고유 사용자 중복 제거 방식 차이로 인해 breakdown별 reach 합산이 전체 reach보다 크게 나올 수 있습니다.

# %% [markdown]
# ## Instagram Insights API 수집 가능 지표 확인

# %%
"""
Instagram Insights API - 계정 & 게시물 전체 지표 수집기
=======================================================
아래 변수를 수정해서 사용하세요:
  - ACCESS_TOKEN   : Meta API 액세스 토큰
  - IG_USER_ID     : Instagram 비즈니스/크리에이터 계정 ID
  - MEDIA_IDS      : 조회할 게시물 ID 목록 (여러 개 가능)

실행:
  pip install facebook-business
  python instagram_insights_fetcher.py
"""

import json
import logging
from datetime import datetime, timedelta
from facebook_business.api import FacebookAdsApi
from facebook_business.adobjects.iguser import IGUser
from facebook_business.adobjects.igmedia import IGMedia

# =============================================================================
# ✏️  여기를 수정하세요
# =============================================================================
ACCESS_TOKEN = "EAALRoZCi9lYQBQZBWWXu67hjLrkvC17V9K5ZAK4UXvYD7Jtx34PvzhWZArK74Yla5xp0TjW6yd4SikRvu51fOCalZARRo36hgQmFQRqKTA3Uy9jy3LIDDl7C3eGSgKgFbEt4FQwEkqGw2TRgEJGDdvIU2xbEsZAjLQQZCGkCij2Gap9ZBPZCZBU3mzg5el8ZCZBftDCV"
APP_ID       = "793452136469892"   # 없으면 빈 문자열
APP_SECRET   = "93c2766fd2a15b7f7997f4586085a4ac"   # 없으면 빈 문자열

IG_USER_ID   = "17841403964728081"      # 예: "17841405822304914"

MEDIA_IDS    = [
    "17978120294869424",                      # 피드 게시물 ID
    # "YOUR_MEDIA_ID_2",                    # 릴스 ID (필요시 추가)
    # "YOUR_MEDIA_ID_3",                    # 스토리 ID (필요시 추가)
]

# 계정 인사이트 조회 기간 (day period 기준)
SINCE_DAYS_AGO = 30   # 오늘 기준 며칠 전부터
# =============================================================================


# 로그 설정
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger(__name__)


# =============================================================================
# 유틸
# =============================================================================

def pretty(data) -> str:
    return json.dumps(data, indent=2, ensure_ascii=False, default=str)

def log_section(title: str):
    log.info("=" * 70)
    log.info(f"  {title}")
    log.info("=" * 70)

def since_until():
    """최근 N일 unix timestamp 반환"""
    now   = datetime.utcnow()
    since = int((now - timedelta(days=SINCE_DAYS_AGO)).timestamp())
    until = int(now.timestamp())
    return since, until


# =============================================================================
# 계정(User) 인사이트
# =============================================================================

def fetch_user_interaction_metrics(ig_user: IGUser):
    """
    계정 레벨 인터랙션 지표 — period=day, metric_type=total_value
    breakdown 가능한 지표: reach(media_product_type, follow_type), views(follow_type, media_product_type)
    """
    since, until = since_until()

    # --- 1) breakdown 없는 인터랙션 지표 전체 ---
    log_section("[계정 1/5] 인터랙션 지표 — breakdown 없음")
    metrics_no_breakdown = [
        "accounts_engaged",
        "reach",
        "views",
        "impressions",          # v22.0+ deprecated, 하위 버전 호환용
        "follows_and_unfollows",
        "likes",
        "comments",
        "shares",
        "saves",
        "replies",
        "reposts",
        "profile_links_taps",
        "total_interactions",
    ]
    params = {
        "metric": ",".join(metrics_no_breakdown),
        "period": "day",
        "metric_type": "total_value",
        "since": since,
        "until": until,
    }
    log.info(f"요청 params: {pretty(params)}")
    try:
        result = ig_user.get_insights(params=params)
        data = [dict(r) for r in result]
        log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
    except Exception as e:
        log.error(f"API 오류: {e}")

    # --- 2) reach — media_product_type breakdown ---
    log_section("[계정 2/5] reach — breakdown: media_product_type")
    params = {
        "metric": "reach",
        "period": "day",
        "metric_type": "total_value",
        "breakdown": "media_product_type",
        "since": since,
        "until": until,
    }
    log.info(f"요청 params: {pretty(params)}")
    try:
        result = ig_user.get_insights(params=params)
        data = [dict(r) for r in result]
        log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
    except Exception as e:
        log.error(f"API 오류: {e}")

    # --- 3) reach — follow_type breakdown ---
    log_section("[계정 3/5] reach — breakdown: follow_type")
    params = {
        "metric": "reach",
        "period": "day",
        "metric_type": "total_value",
        "breakdown": "follow_type",
        "since": since,
        "until": until,
    }
    log.info(f"요청 params: {pretty(params)}")
    try:
        result = ig_user.get_insights(params=params)
        data = [dict(r) for r in result]
        log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
    except Exception as e:
        log.error(f"API 오류: {e}")

    # --- 4) views — follow_type + media_product_type breakdown ---
    log_section("[계정 4/5] views — breakdown: follow_type, media_product_type")
    for bd in ["follow_type", "media_product_type"]:
        params = {
            "metric": "views",
            "period": "day",
            "metric_type": "total_value",
            "breakdown": bd,
            "since": since,
            "until": until,
        }
        log.info(f"breakdown={bd} 요청 params: {pretty(params)}")
        try:
            result = ig_user.get_insights(params=params)
            data = [dict(r) for r in result]
            log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
        except Exception as e:
            log.error(f"API 오류: {e}")


def fetch_user_demographic_metrics(ig_user: IGUser):
    """
    계정 레벨 인구통계 지표 — period=lifetime, timeframe 필수
    breakdown: age / gender / city / country
    """
    timeframe = "last_30_days"

    # --- 5) 인구통계 지표 — 각 breakdown별 ---
    log_section("[계정 5/5] 인구통계 지표 — engaged_audience_demographics & follower_demographics")

    for metric in ["engaged_audience_demographics", "follower_demographics"]:
        for breakdown in ["age", "gender", "city", "country"]:
            params = {
                "metric": metric,
                "period": "lifetime",
                "timeframe": timeframe,
                "metric_type": "total_value",
                "breakdown": breakdown,
            }
            log.info(f"[{metric} / breakdown={breakdown}] 요청 params: {pretty(params)}")
            try:
                result = ig_user.get_insights(params=params)
                data = [dict(r) for r in result]
                log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
            except Exception as e:
                log.error(f"API 오류: {e}")


# =============================================================================
# 미디어(Media) 인사이트
# =============================================================================

# 미디어 타입별 지원 메트릭 정의
# (어떤 타입인지 모를 경우 전부 시도하고 오류 로그로 확인)
MEDIA_METRICS_COMMON = [
    "reach",
    "likes",
    "comments",
    "shares",
    "saved",
    "total_interactions",
    "views",
    "follows",
    "profile_visits",
    "profile_activity",   # breakdown: action_type 지원
]

MEDIA_METRICS_FEED_REELS = [
    # FEED / REELS 전용
]

MEDIA_METRICS_STORY = [
    "replies",
    "navigation",         # breakdown: story_navigation_action_type 지원
]

MEDIA_METRICS_REELS = [
    "ig_reels_avg_watch_time",
    "ig_reels_video_view_total_time",
    # deprecated (요청은 해보되 오류 예상)
    "plays",
    "clips_replays_count",
    "ig_reels_aggregated_all_plays_count",
]

MEDIA_METRICS_DEPRECATED = [
    # 2025.4.21 전면 폐기 — 오류 예상, 확인용으로만 포함
    "impressions",
    "video_views",
]


def fetch_media_insights(media_id: str):
    media = IGMedia(media_id)

    # 미디어 기본 정보 조회 (타입 확인용)
    log_section(f"[미디어 {media_id}] 기본 정보")
    try:
        info = media.api_get(fields=["id", "media_type", "media_product_type", "timestamp", "caption"])
        log.info(f"미디어 정보:\n{pretty(dict(info))}")
    except Exception as e:
        log.error(f"미디어 정보 조회 오류: {e}")

    # --- 공통 지표 — breakdown 없음 ---
    log_section(f"[미디어 {media_id}] 공통 지표 — breakdown 없음")
    _fetch_media_metric(media, MEDIA_METRICS_COMMON + MEDIA_METRICS_DEPRECATED, label="공통+deprecated")

    # --- 스토리 전용 지표 ---
    log_section(f"[미디어 {media_id}] 스토리 전용 지표")
    _fetch_media_metric(media, MEDIA_METRICS_STORY, label="스토리")

    # --- 릴스 전용 지표 ---
    log_section(f"[미디어 {media_id}] 릴스 전용 지표")
    _fetch_media_metric(media, MEDIA_METRICS_REELS, label="릴스")

    # --- profile_activity — breakdown: action_type ---
    log_section(f"[미디어 {media_id}] profile_activity — breakdown: action_type")
    params = {
        "metric": "profile_activity",
        "breakdown": "action_type",
    }
    log.info(f"요청 params: {pretty(params)}")
    try:
        result = media.get_insights(params=params)
        data = [dict(r) for r in result]
        log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
    except Exception as e:
        log.error(f"API 오류: {e}")

    # --- navigation — breakdown: story_navigation_action_type ---
    log_section(f"[미디어 {media_id}] navigation — breakdown: story_navigation_action_type")
    params = {
        "metric": "navigation",
        "breakdown": "story_navigation_action_type",
    }
    log.info(f"요청 params: {pretty(params)}")
    try:
        result = media.get_insights(params=params)
        data = [dict(r) for r in result]
        log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
    except Exception as e:
        log.error(f"API 오류: {e}")


def _fetch_media_metric(media: IGMedia, metrics: list, label: str):
    """미디어 지표를 한 번에 요청. 오류 시 개별 재시도"""
    params = {"metric": ",".join(metrics)}
    log.info(f"[{label}] 요청 metrics: {metrics}")
    try:
        result = media.get_insights(params=params)
        data = [dict(r) for r in result]
        log.info(f"응답 ({len(data)}건):\n{pretty(data)}")
    except Exception as e:
        log.warning(f"일괄 요청 실패 ({e}) → 개별 재시도")
        for m in metrics:
            try:
                result = media.get_insights(params={"metric": m})
                data = [dict(r) for r in result]
                log.info(f"[{m}] 응답 ({len(data)}건):\n{pretty(data)}")
            except Exception as e2:
                log.error(f"[{m}] 오류: {e2}")


# =============================================================================
# 메인
# =============================================================================

def main():
    log.info(f"Instagram Insights 수집 시작 - {datetime.now().isoformat()}")
    log.info(f"IG_USER_ID : {IG_USER_ID}")
    log.info(f"MEDIA_IDS  : {MEDIA_IDS}")
    log.info(f"기간       : 최근 {SINCE_DAYS_AGO}일")

    # API 초기화
    FacebookAdsApi.init(
        app_id=APP_ID or None,
        app_secret=APP_SECRET or None,
        access_token=ACCESS_TOKEN,
    )

    # API 버전 확인
    api = FacebookAdsApi.get_default_api()
    log.info(f"Meta API 버전: {api.API_VERSION}")

    ig_user = IGUser(IG_USER_ID)

    # ── 계정 인사이트 ──────────────────────────────────────────────────────
    log_section("■ 계정(User) 인사이트")
    fetch_user_interaction_metrics(ig_user)
    fetch_user_demographic_metrics(ig_user)

    # ── 미디어 인사이트 ────────────────────────────────────────────────────
    for media_id in MEDIA_IDS:
        log_section(f"■ 미디어 인사이트: {media_id}")
        fetch_media_insights(media_id)

    log.info("=" * 70)
    log.info(f"수집 완료 - {datetime.now().isoformat()}")
    log.info("=" * 70)

    log.warning(
        "⚠️  스토리 지표는 발행 후 24시간 이내에만 조회 가능합니다. "
        "만료된 스토리 ID는 오류가 반환됩니다."
    )
    log.warning(
        "⚠️  인구통계(engaged_audience_demographics / follower_demographics)는 "
        "팔로워 100명 미만 계정에서는 반환되지 않습니다."
    )
    log.warning(
        "⚠️  impressions / plays / clips_replays_count / ig_reels_aggregated_all_plays_count는 "
        "2025년 4월 21일부로 전면 폐기된 지표입니다. 오류가 반환될 수 있습니다."
    )


if __name__ == "__main__":
    main()
# Out:
# 2026-04-15 11:05:38 [INFO] Instagram Insights 수집 시작 - 2026-04-15T11:05:38.459794
# 2026-04-15 11:05:38 [INFO] IG_USER_ID : 17841403964728081
# 2026-04-15 11:05:38 [INFO] MEDIA_IDS  : ['17978120294869424']
# 2026-04-15 11:05:38 [INFO] 기간       : 최근 30일
# 2026-04-15 11:05:38 [INFO] Meta API 버전: v25.0
# 2026-04-15 11:05:38 [INFO] ======================================================================
# 2026-04-15 11:05:38 [INFO]   ■ 계정(User) 인사이트
# 2026-04-15 11:05:38 [INFO] ======================================================================
# 2026-04-15 11:05:38 [INFO] ======================================================================
# 2026-04-15 11:05:38 [INFO]   [계정 1/5] 인터랙션 지표 — breakdown 없음
# 2026-04-15 11:05:38 [INFO] ======================================================================
# 2026-04-15 11:05:38 [INFO] 요청 params: {
#   "metric": "accounts_engaged,reach,views,impressions,follows_and_unfollows,likes,comments,shares,saves,replies,reposts,profile_links_taps,total_interactions",
#   "period": "day",
#   "metric_type": "total_value",
#   "since": 1773594338,
#   "until": 1776186338
# }
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/facebook_business/utils/api_utils.py:16: UserWarning: value of metric might not be compatible.  Expect list<metric_enum>;  got <class 'str'>
#   warnings.warn(message)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/facebook_business/utils/api_utils.py:16: UserWarning: value of period might not be compatible.  Expect list<period_enum>;  got <class 'str'>
#   warnings.warn(message)
# 2026-04-15 11:05:38 [ERROR] API 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17841403964728081/insights
#   Params:  {'metric': 'accounts_engaged,reach,views,impressions,follows_and_unfollows,likes,comments,shares,saves,replies,reposts,profile_links_taps,total_interactions', 'period': 'day', 'metric_type': 'total_value', 'since': 1773594338, 'until': 1776186338}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) metric[3] must be one of the following values: reach, follower_count, website_clicks, profile_views, online_followers, accounts_engaged, total_interactions, likes, comments, shares, saves, replies, engaged_audience_demographics, reached_audience_demographics, follower_demographics, follows_and_unfollows, profile_links_taps, views, threads_likes, threads_replies, reposts, quotes, threads_followers, threads_follower_demographics, content_views, threads_views, threads_clicks, threads_reposts",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "AOtwssTqINJZ3Q1xgy7ZsJc"
#       }
#     }
#
# 2026-04-15 11:05:38 [INFO] ======================================================================
# 2026-04-15 11:05:38 [INFO]   [계정 2/5] reach — breakdown: media_product_type
# 2026-04-15 11:05:38 [INFO] ======================================================================
# 2026-04-15 11:05:38 [INFO] 요청 params: {
#   "metric": "reach",
#   "period": "day",
#   "metric_type": "total_value",
#   "breakdown": "media_product_type",
#   "since": 1773594338,
#   "until": 1776186338
# }
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/facebook_business/utils/api_utils.py:16: UserWarning: value of breakdown might not be compatible.  Expect list<breakdown_enum>;  got <class 'str'>
#   warnings.warn(message)
# 2026-04-15 11:05:39 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/reach/day",
#     "name": "reach",
#     "period": "day",
#     "title": "도달한 계정",
#     "description": "광고를 포함하여 회원님의 콘텐츠를 1회 이상 조회한 고유 계정 수. 콘텐츠에는 게시물, 스토리, 릴스, 동영상 및 라이브 방송이 포함됩니다. 도달은 같은 계정에서 콘텐츠를 여러 번 본 횟수까지 집계하는 노출과는 다른 개념입니다. 이 지표는 추산치이며 개발 중입니다.",
#     "total_value": {
#       "value": 2667,
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "media_product_type"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "CAROUSEL_CONTAINER"
#               ],
#               "value": 1601
#             },
#             {
#               "dimension_values": [
#                 "REEL"
#               ],
#               "value": 1351
#             },
#             {
#               "dimension_values": [
#                 "STORY"
#               ],
#               "value": 353
#             },
#             {
#               "dimension_values": [
#                 "POST"
#               ],
#               "value": 188
#             },
#             {
#               "dimension_values": [
#                 "AD"
#               ],
#               "value": 11
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:39 [INFO] ======================================================================
# 2026-04-15 11:05:39 [INFO]   [계정 3/5] reach — breakdown: follow_type
# 2026-04-15 11:05:39 [INFO] ======================================================================
# 2026-04-15 11:05:39 [INFO] 요청 params: {
#   "metric": "reach",
#   "period": "day",
#   "metric_type": "total_value",
#   "breakdown": "follow_type",
#   "since": 1773594338,
#   "until": 1776186338
# }
# 2026-04-15 11:05:40 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/reach/day",
#     "name": "reach",
#     "period": "day",
#     "title": "도달한 계정",
#     "description": "광고를 포함하여 회원님의 콘텐츠를 1회 이상 조회한 고유 계정 수. 콘텐츠에는 게시물, 스토리, 릴스, 동영상 및 라이브 방송이 포함됩니다. 도달은 같은 계정에서 콘텐츠를 여러 번 본 횟수까지 집계하는 노출과는 다른 개념입니다. 이 지표는 추산치이며 개발 중입니다.",
#     "total_value": {
#       "value": 2667,
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "follow_type"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "NON_FOLLOWER"
#               ],
#               "value": 1737
#             },
#             {
#               "dimension_values": [
#                 "FOLLOWER"
#               ],
#               "value": 939
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:40 [INFO] ======================================================================
# 2026-04-15 11:05:40 [INFO]   [계정 4/5] views — breakdown: follow_type, media_product_type
# 2026-04-15 11:05:40 [INFO] ======================================================================
# 2026-04-15 11:05:40 [INFO] breakdown=follow_type 요청 params: {
#   "metric": "views",
#   "period": "day",
#   "metric_type": "total_value",
#   "breakdown": "follow_type",
#   "since": 1773594338,
#   "until": 1776186338
# }
# 2026-04-15 11:05:40 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/views/day",
#     "name": "views",
#     "period": "day",
#     "title": "조회수",
#     "description": "콘텐츠가 재생되거나 표시된 횟수. 콘텐츠에는 릴스, 게시물, 스토리가 포함됩니다.",
#     "total_value": {
#       "value": 13822,
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "follow_type"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "UNKNOWN"
#               ],
#               "value": 13
#             },
#             {
#               "dimension_values": [
#                 "FOLLOWER"
#               ],
#               "value": 9669
#             },
#             {
#               "dimension_values": [
#                 "NON_FOLLOWER"
#               ],
#               "value": 4140
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:40 [INFO] breakdown=media_product_type 요청 params: {
#   "metric": "views",
#   "period": "day",
#   "metric_type": "total_value",
#   "breakdown": "media_product_type",
#   "since": 1773594338,
#   "until": 1776186338
# }
# 2026-04-15 11:05:40 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/views/day",
#     "name": "views",
#     "period": "day",
#     "title": "조회수",
#     "description": "콘텐츠가 재생되거나 표시된 횟수. 콘텐츠에는 릴스, 게시물, 스토리가 포함됩니다.",
#     "total_value": {
#       "value": 13822,
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "media_product_type"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "REEL"
#               ],
#               "value": 2826
#             },
#             {
#               "dimension_values": [
#                 "STORY"
#               ],
#               "value": 2022
#             },
#             {
#               "dimension_values": [
#                 "CAROUSEL_CONTAINER"
#               ],
#               "value": 8911
#             },
#             {
#               "dimension_values": [
#                 "AD"
#               ],
#               "value": 11
#             },
#             {
#               "dimension_values": [
#                 "POST"
#               ],
#               "value": 52
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:40 [INFO] ======================================================================
# 2026-04-15 11:05:40 [INFO]   [계정 5/5] 인구통계 지표 — engaged_audience_demographics & follower_demographics
# 2026-04-15 11:05:40 [INFO] ======================================================================
# 2026-04-15 11:05:40 [INFO] [engaged_audience_demographics / breakdown=age] 요청 params: {
#   "metric": "engaged_audience_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "age"
# }
# 2026-04-15 11:05:41 [ERROR] API 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17841403964728081/insights
#   Params:  {'metric': 'engaged_audience_demographics', 'period': 'lifetime', 'timeframe': 'last_30_days', 'metric_type': 'total_value', 'breakdown': 'age'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The timeframe parameter specified last_30_days is no longer supported for engaged_audience_demographics and reached_audience_demographics starting from version 20+. Instead, please refer to the documentation https://developers.facebook.com/docs/instagram-api/reference/ig-user/insights for the currently supported timeframe parameters",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A8K0xWNElZYvpBi4h817J1f"
#       }
#     }
#
# 2026-04-15 11:05:41 [INFO] [engaged_audience_demographics / breakdown=gender] 요청 params: {
#   "metric": "engaged_audience_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "gender"
# }
# 2026-04-15 11:05:41 [ERROR] API 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17841403964728081/insights
#   Params:  {'metric': 'engaged_audience_demographics', 'period': 'lifetime', 'timeframe': 'last_30_days', 'metric_type': 'total_value', 'breakdown': 'gender'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The timeframe parameter specified last_30_days is no longer supported for engaged_audience_demographics and reached_audience_demographics starting from version 20+. Instead, please refer to the documentation https://developers.facebook.com/docs/instagram-api/reference/ig-user/insights for the currently supported timeframe parameters",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A3B2-ncz7C8araqwAq6rqGg"
#       }
#     }
#
# 2026-04-15 11:05:41 [INFO] [engaged_audience_demographics / breakdown=city] 요청 params: {
#   "metric": "engaged_audience_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "city"
# }
# 2026-04-15 11:05:41 [ERROR] API 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17841403964728081/insights
#   Params:  {'metric': 'engaged_audience_demographics', 'period': 'lifetime', 'timeframe': 'last_30_days', 'metric_type': 'total_value', 'breakdown': 'city'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The timeframe parameter specified last_30_days is no longer supported for engaged_audience_demographics and reached_audience_demographics starting from version 20+. Instead, please refer to the documentation https://developers.facebook.com/docs/instagram-api/reference/ig-user/insights for the currently supported timeframe parameters",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "AlavcGyTXwCvPY_PBGdmnhW"
#       }
#     }
#
# 2026-04-15 11:05:41 [INFO] [engaged_audience_demographics / breakdown=country] 요청 params: {
#   "metric": "engaged_audience_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "country"
# }
# 2026-04-15 11:05:42 [ERROR] API 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17841403964728081/insights
#   Params:  {'metric': 'engaged_audience_demographics', 'period': 'lifetime', 'timeframe': 'last_30_days', 'metric_type': 'total_value', 'breakdown': 'country'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The timeframe parameter specified last_30_days is no longer supported for engaged_audience_demographics and reached_audience_demographics starting from version 20+. Instead, please refer to the documentation https://developers.facebook.com/docs/instagram-api/reference/ig-user/insights for the currently supported timeframe parameters",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "Abh-KKtiJEmEy2eT_CpAdOI"
#       }
#     }
#
# 2026-04-15 11:05:42 [INFO] [follower_demographics / breakdown=age] 요청 params: {
#   "metric": "follower_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "age"
# }
# 2026-04-15 11:05:42 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/follower_demographics/lifetime",
#     "name": "follower_demographics",
#     "period": "lifetime",
#     "title": "팔로워의 인구 통계학적 특성",
#     "description": "팔로워의 국가, 도시, 성별 분포 등 인구 통계학적 특성.",
#     "total_value": {
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "age"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "13-17"
#               ],
#               "value": 9
#             },
#             {
#               "dimension_values": [
#                 "18-24"
#               ],
#               "value": 277
#             },
#             {
#               "dimension_values": [
#                 "25-34"
#               ],
#               "value": 1803
#             },
#             {
#               "dimension_values": [
#                 "35-44"
#               ],
#               "value": 3322
#             },
#             {
#               "dimension_values": [
#                 "45-54"
#               ],
#               "value": 1555
#             },
#             {
#               "dimension_values": [
#                 "55-64"
#               ],
#               "value": 296
#             },
#             {
#               "dimension_values": [
#                 "65+"
#               ],
#               "value": 80
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:42 [INFO] [follower_demographics / breakdown=gender] 요청 params: {
#   "metric": "follower_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "gender"
# }
# 2026-04-15 11:05:42 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/follower_demographics/lifetime",
#     "name": "follower_demographics",
#     "period": "lifetime",
#     "title": "팔로워의 인구 통계학적 특성",
#     "description": "팔로워의 국가, 도시, 성별 분포 등 인구 통계학적 특성.",
#     "total_value": {
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "gender"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "F"
#               ],
#               "value": 3695
#             },
#             {
#               "dimension_values": [
#                 "M"
#               ],
#               "value": 944
#             },
#             {
#               "dimension_values": [
#                 "U"
#               ],
#               "value": 2703
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:42 [INFO] [follower_demographics / breakdown=city] 요청 params: {
#   "metric": "follower_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "city"
# }
# 2026-04-15 11:05:43 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/follower_demographics/lifetime",
#     "name": "follower_demographics",
#     "period": "lifetime",
#     "title": "팔로워의 인구 통계학적 특성",
#     "description": "팔로워의 국가, 도시, 성별 분포 등 인구 통계학적 특성.",
#     "total_value": {
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "city"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "Jeju, Jeju-do"
#               ],
#               "value": 51
#             },
#             {
#               "dimension_values": [
#                 "Wonju, Gangwon-do"
#               ],
#               "value": 39
#             },
#             {
#               "dimension_values": [
#                 "Gwangju, Gwangju"
#               ],
#               "value": 129
#             },
#             {
#               "dimension_values": [
#                 "Yongin, Gyeonggi-do"
#               ],
#               "value": 145
#             },
#             {
#               "dimension_values": [
#                 "Daegu, Daegu"
#               ],
#               "value": 276
#             },
#             {
#               "dimension_values": [
#                 "Hong Kong, Hong Kong"
#               ],
#               "value": 51
#             },
#             {
#               "dimension_values": [
#                 "Busan, Busan"
#               ],
#               "value": 334
#             },
#             {
#               "dimension_values": [
#                 "Seoul, Seoul"
#               ],
#               "value": 1959
#             },
#             {
#               "dimension_values": [
#                 "Goyang, Gyeonggi-do"
#               ],
#               "value": 148
#             },
#             {
#               "dimension_values": [
#                 "Pohang, Gyeongsangbuk-do"
#               ],
#               "value": 58
#             },
#             {
#               "dimension_values": [
#                 "Geoje, Gyeongsangnam-do"
#               ],
#               "value": 29
#             },
#             {
#               "dimension_values": [
#                 "Ho Chi Minh City, Ho Chi Minh City"
#               ],
#               "value": 81
#             },
#             {
#               "dimension_values": [
#                 "Namyangju, Gyeonggi-do"
#               ],
#               "value": 91
#             },
#             {
#               "dimension_values": [
#                 "Yeosu, Jeollanam-do"
#               ],
#               "value": 30
#             },
#             {
#               "dimension_values": [
#                 "Shanghai, Shanghai"
#               ],
#               "value": 42
#             },
#             {
#               "dimension_values": [
#                 "Gumi, Gyeongsangbuk-do"
#               ],
#               "value": 48
#             },
#             {
#               "dimension_values": [
#                 "Xinbei, New Taipei City"
#               ],
#               "value": 55
#             },
#             {
#               "dimension_values": [
#                 "Gimpo, Gyeonggi-do"
#               ],
#               "value": 85
#             },
#             {
#               "dimension_values": [
#                 "Hanam, Gyeonggi-do"
#               ],
#               "value": 45
#             },
#             {
#               "dimension_values": [
#                 "Incheon, Incheon"
#               ],
#               "value": 380
#             },
#             {
#               "dimension_values": [
#                 "Guri, Gyeonggi-do"
#               ],
#               "value": 30
#             },
#             {
#               "dimension_values": [
#                 "Icheon, Gyeonggi-do"
#               ],
#               "value": 33
#             },
#             {
#               "dimension_values": [
#                 "Jeonju, Jeollabuk-do"
#               ],
#               "value": 60
#             },
#             {
#               "dimension_values": [
#                 "Hwaseong, Gyeonggi-do"
#               ],
#               "value": 97
#             },
#             {
#               "dimension_values": [
#                 "Asan, Chungcheongnam-do"
#               ],
#               "value": 42
#             },
#             {
#               "dimension_values": [
#                 "Yangsan, Gyeongsangnam-do"
#               ],
#               "value": 73
#             },
#             {
#               "dimension_values": [
#                 "Daejeon, Daejeon"
#               ],
#               "value": 137
#             },
#             {
#               "dimension_values": [
#                 "Ansan, Gyeonggi-do"
#               ],
#               "value": 66
#             },
#             {
#               "dimension_values": [
#                 "Anyang, Gyeonggi-do"
#               ],
#               "value": 69
#             },
#             {
#               "dimension_values": [
#                 "Changwon, Gyeongsangnam-do"
#               ],
#               "value": 97
#             },
#             {
#               "dimension_values": [
#                 "Cheonan, Chungcheongnam-do"
#               ],
#               "value": 62
#             },
#             {
#               "dimension_values": [
#                 "Bucheon, Gyeonggi-do"
#               ],
#               "value": 76
#             },
#             {
#               "dimension_values": [
#                 "Cheongju, Chungcheongbuk-do"
#               ],
#               "value": 82
#             },
#             {
#               "dimension_values": [
#                 "Suwon, Gyeonggi-do"
#               ],
#               "value": 147
#             },
#             {
#               "dimension_values": [
#                 "Gwangju, Gyeonggi-do"
#               ],
#               "value": 51
#             },
#             {
#               "dimension_values": [
#                 "Ulsan, Ulsan"
#               ],
#               "value": 114
#             },
#             {
#               "dimension_values": [
#                 "Pyeongtaek, Gyeonggi-do"
#               ],
#               "value": 77
#             },
#             {
#               "dimension_values": [
#                 "Uijeongbu, Gyeonggi-do"
#               ],
#               "value": 49
#             },
#             {
#               "dimension_values": [
#                 "Gimhae, Gyeongsangnam-do"
#               ],
#               "value": 52
#             },
#             {
#               "dimension_values": [
#                 "Seongnam, Gyeonggi-do"
#               ],
#               "value": 106
#             },
#             {
#               "dimension_values": [
#                 "Taichung, Taichung"
#               ],
#               "value": 29
#             },
#             {
#               "dimension_values": [
#                 "Siheung, Gyeonggi-do"
#               ],
#               "value": 56
#             },
#             {
#               "dimension_values": [
#                 "Gwangmyeong, Gyeonggi-do"
#               ],
#               "value": 30
#             },
#             {
#               "dimension_values": [
#                 "Chungju, Chungcheongbuk-do"
#               ],
#               "value": 27
#             },
#             {
#               "dimension_values": [
#                 "Paju, Gyeonggi-do"
#               ],
#               "value": 83
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:43 [INFO] [follower_demographics / breakdown=country] 요청 params: {
#   "metric": "follower_demographics",
#   "period": "lifetime",
#   "timeframe": "last_30_days",
#   "metric_type": "total_value",
#   "breakdown": "country"
# }
# 2026-04-15 11:05:43 [INFO] 응답 (1건):
# [
#   {
#     "id": "17841403964728081/insights/follower_demographics/lifetime",
#     "name": "follower_demographics",
#     "period": "lifetime",
#     "title": "팔로워의 인구 통계학적 특성",
#     "description": "팔로워의 국가, 도시, 성별 분포 등 인구 통계학적 특성.",
#     "total_value": {
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "country"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "RU"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "HK"
#               ],
#               "value": 51
#             },
#             {
#               "dimension_values": [
#                 "TW"
#               ],
#               "value": 185
#             },
#             {
#               "dimension_values": [
#                 "PT"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "JP"
#               ],
#               "value": 50
#             },
#             {
#               "dimension_values": [
#                 "DO"
#               ],
#               "value": 3
#             },
#             {
#               "dimension_values": [
#                 "NZ"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "BO"
#               ],
#               "value": 3
#             },
#             {
#               "dimension_values": [
#                 "HU"
#               ],
#               "value": 4
#             },
#             {
#               "dimension_values": [
#                 "SA"
#               ],
#               "value": 3
#             },
#             {
#               "dimension_values": [
#                 "BR"
#               ],
#               "value": 83
#             },
#             {
#               "dimension_values": [
#                 "MA"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "SG"
#               ],
#               "value": 10
#             },
#             {
#               "dimension_values": [
#                 "ID"
#               ],
#               "value": 17
#             },
#             {
#               "dimension_values": [
#                 "KH"
#               ],
#               "value": 5
#             },
#             {
#               "dimension_values": [
#                 "EC"
#               ],
#               "value": 4
#             },
#             {
#               "dimension_values": [
#                 "CA"
#               ],
#               "value": 14
#             },
#             {
#               "dimension_values": [
#                 "US"
#               ],
#               "value": 60
#             },
#             {
#               "dimension_values": [
#                 "MM"
#               ],
#               "value": 6
#             },
#             {
#               "dimension_values": [
#                 "MN"
#               ],
#               "value": 6
#             },
#             {
#               "dimension_values": [
#                 "MO"
#               ],
#               "value": 6
#             },
#             {
#               "dimension_values": [
#                 "IN"
#               ],
#               "value": 7
#             },
#             {
#               "dimension_values": [
#                 "KR"
#               ],
#               "value": 6411
#             },
#             {
#               "dimension_values": [
#                 "IQ"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "CL"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "IR"
#               ],
#               "value": 8
#             },
#             {
#               "dimension_values": [
#                 "IT"
#               ],
#               "value": 3
#             },
#             {
#               "dimension_values": [
#                 "MX"
#               ],
#               "value": 13
#             },
#             {
#               "dimension_values": [
#                 "CN"
#               ],
#               "value": 125
#             },
#             {
#               "dimension_values": [
#                 "CO"
#               ],
#               "value": 4
#             },
#             {
#               "dimension_values": [
#                 "MY"
#               ],
#               "value": 13
#             },
#             {
#               "dimension_values": [
#                 "ES"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "KZ"
#               ],
#               "value": 5
#             },
#             {
#               "dimension_values": [
#                 "AR"
#               ],
#               "value": 3
#             },
#             {
#               "dimension_values": [
#                 "AT"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "AU"
#               ],
#               "value": 14
#             },
#             {
#               "dimension_values": [
#                 "TH"
#               ],
#               "value": 29
#             },
#             {
#               "dimension_values": [
#                 "PE"
#               ],
#               "value": 3
#             },
#             {
#               "dimension_values": [
#                 "LB"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "PH"
#               ],
#               "value": 14
#             },
#             {
#               "dimension_values": [
#                 "VN"
#               ],
#               "value": 113
#             },
#             {
#               "dimension_values": [
#                 "PL"
#               ],
#               "value": 5
#             },
#             {
#               "dimension_values": [
#                 "NL"
#               ],
#               "value": 2
#             },
#             {
#               "dimension_values": [
#                 "TR"
#               ],
#               "value": 6
#             },
#             {
#               "dimension_values": [
#                 "LK"
#               ],
#               "value": 3
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:43 [INFO] ======================================================================
# 2026-04-15 11:05:43 [INFO]   ■ 미디어 인사이트: 17978120294869424
# 2026-04-15 11:05:43 [INFO] ======================================================================
# 2026-04-15 11:05:43 [INFO] ======================================================================
# 2026-04-15 11:05:43 [INFO]   [미디어 17978120294869424] 기본 정보
# 2026-04-15 11:05:43 [INFO] ======================================================================
# 2026-04-15 11:05:43 [INFO] 미디어 정보:
# {
#   "id": "17978120294869424",
#   "media_type": "CAROUSEL_ALBUM",
#   "media_product_type": "FEED",
#   "timestamp": "2025-08-30T08:30:12+0000",
#   "caption": "오늘도 커피로 하루를 시작하셨나요? ☕️\n\n출근길, 점심 식사 후, 오후의 나른함까지\n우리는 하루에도 여러 번, 습관처럼 커피를 찾습니다\n\n커피 속 카페인은 중추신경을 자극해\n집중력 향상과 피로 회복하는데 도움을 주죠\n하지만 과도한 카페인 섭취는\n불면증, 속 쓰림 같은 불편함을 유발할 수 있어요\n\n그럴 땐, #오늘은그린커피빈 으로\n하루를 시작해 보세요\n\n부담스러운 카페인은 줄이고,\n은은한 헤이즐넛 향은 즐길 수 있어요\n\n체지방 감소 성분인 클로로겐산이 담겨 있어\n건강한 다이어트에도 도움을 줄 수 있어요\n\n하루 루틴의 시작, NGT\n\n#NGT #네츄럴굿띵스 #다이어트커피\n#체지방관리 #다이어트보조제"
# }
# 2026-04-15 11:05:43 [INFO] ======================================================================
# 2026-04-15 11:05:43 [INFO]   [미디어 17978120294869424] 공통 지표 — breakdown 없음
# 2026-04-15 11:05:43 [INFO] ======================================================================
# 2026-04-15 11:05:43 [INFO] [공통+deprecated] 요청 metrics: ['reach', 'likes', 'comments', 'shares', 'saved', 'total_interactions', 'views', 'follows', 'profile_visits', 'profile_activity', 'impressions', 'video_views']
# 2026-04-15 11:05:44 [WARNING] 일괄 요청 실패 (
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'reach,likes,comments,shares,saved,total_interactions,views,follows,profile_visits,profile_activity,impressions,video_views'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) Starting from version v22.0 and above, the impressions metric is no longer supported for the queried media. Please refer to the documentation at https://developers.facebook.com/docs/instagram-api/reference/ig-media/insights for a list of supported metrics.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A7T3HAXu1Sq6JrnTn_L4y1p"
#       }
#     }
# ) → 개별 재시도
# 2026-04-15 11:05:44 [INFO] [reach] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/reach/lifetime",
#     "name": "reach",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 575
#       }
#     ],
#     "title": "도달한 계정",
#     "description": "이 슬라이드 컨테이너를 한 번 이상 본 고유 계정 수. 도달은 같은 계정에서 슬라이드 컨테이너를 여러 번 본 횟수까지 집계하는 노출과는 다른 개념입니다. 이 지표는 추산치입니다."
#   }
# ]
# 2026-04-15 11:05:45 [INFO] [likes] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/likes/lifetime",
#     "name": "likes",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 23
#       }
#     ],
#     "title": "좋아요",
#     "description": "게시물의 좋아요 수."
#   }
# ]
# 2026-04-15 11:05:45 [INFO] [comments] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/comments/lifetime",
#     "name": "comments",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 0
#       }
#     ],
#     "title": "댓글",
#     "description": "게시물의 댓글 수."
#   }
# ]
# 2026-04-15 11:05:45 [INFO] [shares] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/shares/lifetime",
#     "name": "shares",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 1
#       }
#     ],
#     "title": "공유",
#     "description": "게시물이 공유된 횟수."
#   }
# ]
# 2026-04-15 11:05:46 [INFO] [saved] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/saved/lifetime",
#     "name": "saved",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 4
#       }
#     ],
#     "title": "저장됨",
#     "description": "게시물 저장 횟수."
#   }
# ]
# 2026-04-15 11:05:46 [INFO] [total_interactions] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/total_interactions/lifetime",
#     "name": "total_interactions",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 28
#       }
#     ],
#     "title": "게시물 반응",
#     "description": "게시물의 좋아요, 저장, 댓글 및 공유 수에서 좋아요 취소, 저장 취소 및 삭제된 댓글 수를 뺀 값."
#   }
# ]
# 2026-04-15 11:05:46 [INFO] [views] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/views/lifetime",
#     "name": "views",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 4680
#       }
#     ],
#     "title": "조회수",
#     "description": "게시물이 재생되거나 표시된 횟수."
#   }
# ]
# 2026-04-15 11:05:47 [INFO] [follows] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/follows/lifetime",
#     "name": "follows",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 1
#       }
#     ],
#     "title": "팔로우",
#     "description": "회원님을 팔로우하는 계정 수입니다."
#   }
# ]
# 2026-04-15 11:05:47 [INFO] [profile_visits] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/profile_visits/lifetime",
#     "name": "profile_visits",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 10
#       }
#     ],
#     "title": "프로필 방문",
#     "description": "사람들이 회원님의 프로필을 방문한 횟수입니다."
#   }
# ]
# 2026-04-15 11:05:48 [INFO] [profile_activity] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/profile_activity/lifetime",
#     "name": "profile_activity",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 4
#       }
#     ],
#     "title": "프로필 활동",
#     "description": "[IG 인사이트] 이 헤더는 특정 게시물, 스토리, 동영상 또는 홍보의 교육용 정보 시트에 표시되는 지표의 이름입니다. 이 지표는 사람들이 이 콘텐츠에 참여할 때 취하는 모든 프로필 행동의 합계입니다."
#   }
# ]
# 2026-04-15 11:05:48 [ERROR] [impressions] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'impressions'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) Starting from version v22.0 and above, the impressions metric is no longer supported for the queried media. Please refer to the documentation at https://developers.facebook.com/docs/instagram-api/reference/ig-media/insights for a list of supported metrics.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "AZ2CLWp3bobvSJbGI3BGm8u"
#       }
#     }
#
# 2026-04-15 11:05:48 [ERROR] [video_views] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'video_views'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the video_views metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "ApKwu7IKdAfc1LW7pzWheHy"
#       }
#     }
#
# 2026-04-15 11:05:48 [INFO] ======================================================================
# 2026-04-15 11:05:48 [INFO]   [미디어 17978120294869424] 스토리 전용 지표
# 2026-04-15 11:05:48 [INFO] ======================================================================
# 2026-04-15 11:05:48 [INFO] [스토리] 요청 metrics: ['replies', 'navigation']
# 2026-04-15 11:05:49 [WARNING] 일괄 요청 실패 (
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'replies,navigation'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the replies, navigation metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A7CiA1c8RIyOqjBgWce9vhg"
#       }
#     }
# ) → 개별 재시도
# 2026-04-15 11:05:49 [ERROR] [replies] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'replies'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the replies metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "AdFWh3xL4RO68n8e99WuKNE"
#       }
#     }
#
# 2026-04-15 11:05:49 [ERROR] [navigation] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'navigation'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the navigation metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A1Wa_URikwjs-E4-Xqjj82_"
#       }
#     }
#
# 2026-04-15 11:05:49 [INFO] ======================================================================
# 2026-04-15 11:05:49 [INFO]   [미디어 17978120294869424] 릴스 전용 지표
# 2026-04-15 11:05:49 [INFO] ======================================================================
# 2026-04-15 11:05:49 [INFO] [릴스] 요청 metrics: ['ig_reels_avg_watch_time', 'ig_reels_video_view_total_time', 'plays', 'clips_replays_count', 'ig_reels_aggregated_all_plays_count']
# 2026-04-15 11:05:49 [WARNING] 일괄 요청 실패 (
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'ig_reels_avg_watch_time,ig_reels_video_view_total_time,plays,clips_replays_count,ig_reels_aggregated_all_plays_count'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the ig_reels_avg_watch_time, ig_reels_video_view_total_time, plays, clips_replays_count, ig_reels_aggregated_all_plays_count metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A0zbASgxMML2e77IvF7a64z"
#       }
#     }
# ) → 개별 재시도
# 2026-04-15 11:05:50 [ERROR] [ig_reels_avg_watch_time] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'ig_reels_avg_watch_time'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the ig_reels_avg_watch_time metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "AIMDVpZyVhCeeswpy3DPita"
#       }
#     }
#
# 2026-04-15 11:05:50 [ERROR] [ig_reels_video_view_total_time] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'ig_reels_video_view_total_time'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the ig_reels_video_view_total_time metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "ALn7d6aNcItO0Mx-mvvsaEI"
#       }
#     }
#
# 2026-04-15 11:05:51 [ERROR] [plays] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'plays'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the plays metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "Av-HTGczaI6RKxmyjm-uo9J"
#       }
#     }
#
# 2026-04-15 11:05:51 [ERROR] [clips_replays_count] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'clips_replays_count'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the clips_replays_count metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "A1G6Cw1qzPHwqzZgbXZbtdE"
#       }
#     }
#
# 2026-04-15 11:05:51 [ERROR] [ig_reels_aggregated_all_plays_count] 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'ig_reels_aggregated_all_plays_count'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the ig_reels_aggregated_all_plays_count metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "AZRnHtaEbFs2HnjTy9linSc"
#       }
#     }
#
# 2026-04-15 11:05:51 [INFO] ======================================================================
# 2026-04-15 11:05:51 [INFO]   [미디어 17978120294869424] profile_activity — breakdown: action_type
# 2026-04-15 11:05:51 [INFO] ======================================================================
# 2026-04-15 11:05:51 [INFO] 요청 params: {
#   "metric": "profile_activity",
#   "breakdown": "action_type"
# }
# 2026-04-15 11:05:52 [INFO] 응답 (1건):
# [
#   {
#     "id": "17978120294869424/insights/profile_activity/lifetime",
#     "name": "profile_activity",
#     "period": "lifetime",
#     "values": [
#       {
#         "value": 4
#       }
#     ],
#     "title": "프로필 활동",
#     "description": "[IG 인사이트] 이 헤더는 특정 게시물, 스토리, 동영상 또는 홍보의 교육용 정보 시트에 표시되는 지표의 이름입니다. 이 지표는 사람들이 이 콘텐츠에 참여할 때 취하는 모든 프로필 행동의 합계입니다.",
#     "total_value": {
#       "value": 4,
#       "breakdowns": [
#         {
#           "dimension_keys": [
#             "action_type"
#           ],
#           "results": [
#             {
#               "dimension_values": [
#                 "bio_link_clicked"
#               ],
#               "value": 4
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# 2026-04-15 11:05:52 [INFO] ======================================================================
# 2026-04-15 11:05:52 [INFO]   [미디어 17978120294869424] navigation — breakdown: story_navigation_action_type
# 2026-04-15 11:05:52 [INFO] ======================================================================
# 2026-04-15 11:05:52 [INFO] 요청 params: {
#   "metric": "navigation",
#   "breakdown": "story_navigation_action_type"
# }
# 2026-04-15 11:05:52 [ERROR] API 오류:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v25.0/17978120294869424/insights
#   Params:  {'metric': 'navigation', 'breakdown': 'story_navigation_action_type'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#100) The Media Insights API does not support the navigation metric for this media product type.",
#         "type": "OAuthException",
#         "code": 100,
#         "fbtrace_id": "AXnqt5397cwfGzd-V6SGzvk"
#       }
#     }
#
# 2026-04-15 11:05:52 [INFO] ======================================================================
# 2026-04-15 11:05:52 [INFO] 수집 완료 - 2026-04-15T11:05:52.615803
# 2026-04-15 11:05:52 [INFO] ======================================================================
# 2026-04-15 11:05:52 [WARNING] ⚠️  스토리 지표는 발행 후 24시간 이내에만 조회 가능합니다. 만료된 스토리 ID는 오류가 반환됩니다.
# 2026-04-15 11:05:52 [WARNING] ⚠️  인구통계(engaged_audience_demographics / follower_demographics)는 팔로워 100명 미만 계정에서는 반환되지 않습니다.
# 2026-04-15 11:05:52 [WARNING] ⚠️  impressions / plays / clips_replays_count / ig_reels_aggregated_all_plays_count는 2025년 4월 21일부로 전면 폐기된 지표입니다. 오류가 반환될 수 있습니다.
